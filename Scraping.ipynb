# %%
import requests

# %%
url = "https://en.wikipedia.org/wiki/Special:Random"

# %%
response = requests.get(url)
content = response.text
print(content)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Rocky Mount, Virginia - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
start= content.find("<title>")
end = content.find("</title>")
print(content[start+len("<title>"):end-len("- Wikipedia")])
# Out:
# Rocky Mount, Virginia

# %%
import requests

# %%
url = "https://timesofindia.indiatimes.com/"

# %%
response = requests.get(url)
content = response.text
print(content)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd" ><html xmlns:g="http://base.google.com/ns/1.0" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><script src="//cdn.optimizely.com/js/83181943.js"></script><meta charset="utf-8"><title>News: India News, Latest Bollywood News, Sports News, Business &amp; Political News, National &amp; International News | Times of India</title><meta http-equiv="Last-Modified" content="Saturday, 23 March, 2019 11:48:44AM"><meta name="Last-Modified" content="Saturday, 23 March, 2019 11:48:44AM"><meta name="Last-Modified-Date" content="Sat, Mar 23, 2019"><meta name="Last-Modified-Time" content="11.48AM IST"><meta content="Times of India brings the Latest News &amp; Top Breaking headlines on Politics and Current Affairs in India &amp; around the World, Sports, Business, Bollywood News and Entertain
# ...

# %%
start= content.find("Story_View-2-geturl~Top_News_Stories")
raw_data=(content[start:start+500])
print(raw_data)
# Out:
# Story_View-2-geturl~Top_News_Stories" title="Lalu&rsquo;s RJD to fight lowest-ever number of seats" href="/india/lalus-rjd-to-fight-lowest-ever-number-of-seats-gives-half-to-allies/articleshow/68530494.cms">Lalu&rsquo;s RJD to fight lowest-ever number of seats</a><a href="/india/lalus-rjd-to-fight-lowest-ever-number-of-seats-gives-half-to-allies/articleshow/68530494.cms" pg="#Story_View-2-geturl~Top_News_Stories"><i class="icon_video"></i></a></li><li><a pg="#Story_View-3-geturl~Top_News_Stories

# %%
start = raw_data.find("title=")
end = raw_data.find("href")
print(raw_data[start+len("title="):end])
# Out:
# "Lalu&rsquo;s RJD to fight lowest-ever number of seats"

# %%
import requests

# %%
url= "https://timesofindia.indiatimes.com/"

# %%
response = requests.get(url)
content = response.text
print(content)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd" ><html xmlns:g="http://base.google.com/ns/1.0" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><script src="//cdn.optimizely.com/js/83181943.js"></script><meta charset="utf-8"><title>News: India News, Latest Bollywood News, Sports News, Business &amp; Political News, National &amp; International News | Times of India</title><meta http-equiv="Last-Modified" content="Saturday, 23 March, 2019 12:20:47PM"><meta name="Last-Modified" content="Saturday, 23 March, 2019 12:20:47PM"><meta name="Last-Modified-Date" content="Sat, Mar 23, 2019"><meta name="Last-Modified-Time" content="12.20PM IST"><meta content="Times of India brings the Latest News &amp; Top Breaking headlines on Politics and Current Affairs in India &amp; around the World, Sports, Business, Bollywood News and Entertain
# ...

# %%
import requests

# %%
url= "https://www.amazon.in/All-new-Echo-Dot-3rd-Gen/dp/B0792KTHKK/ref=sr_1_2?crid=20CTJK26SHUZD&keywords=all+new+echo+dot+3rd+gen&qid=1553324291&s=gateway&sprefix=all+new%2Caps%2C253&sr=8-2"

# %%
response = requests.get(url)
content = response.text
print(content)
# Out:
# <!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"><!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'><link rel='dns-prefetch' href='//images-eu.ssl-images-amazon.com'><link rel='dns-prefetch' href='//m.media-amazon.com'><link rel='dns-prefetch' href='//completion.amazon.com'><!-- sp:feature:aui-assets -->
# ...

# %%
start = content.find('id="productTitle"')
raw_data = (content[start:start+350])
print(raw_data)
# Out:
# id="productTitle" class="a-size-large">
#
#
#
#
#
#
#
#
#                         All-new Echo Dot (3rd Gen) - Smart speaker with Alexa (Black)

# %%
print(raw_data[len('id="productTitle" class="a-size-large">'):300])
# Out:
#
#
#
#
#
#
#
#
#                         All-new Echo Dot (3rd Gen) - Smart speaker with Alexa (Black)

# %%
rating_start = content.find('class="a-icon-alt"')
rating_end = (content[rating_start:rating_start+100])
print(rating_end)
# Out:
# class="a-icon-alt">3.8 out of 5 stars</span></i>
#
#             <i class="a-icon a-ico

# %%
end=rating_end.find('</span')
print (rating_end[len('class="a-icon-alt">'):end])
# Out:
# 3.8 out of 5 stars

# %%
start = content.find('class="currencyINR"')

# %%
import requests

x= input("enter any url")
# Out:
# enter any urlwww.google.com

# %%
url = (x)

# %%
response = requests.get(url)
content = response.text
print(content)
# Out:
# <!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"><!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'><link rel='dns-prefetch' href='//images-eu.ssl-images-amazon.com'><link rel='dns-prefetch' href='//m.media-amazon.com'><link rel='dns-prefetch' href='//completion.amazon.com'><!-- sp:feature:aui-assets -->
# ...

# %%
start= content.find('id="productTitle"')
raw1 = content[start+len('id="productTitle" class="a-size-large">'):]
print(raw1)
# Out:
#
#
#
#
#
#
#
#
#                         All-new Echo Dot (3rd Gen) - Smart speaker with Alexa (Black)
#
#
#
#
#
#
#
#             </span>
#
#
#
#
#
#
#
#
#         </h1>
#
#         <div id="expandTitleToggle" class="a-section a-spacing-none expand aok-hidden"></div>
#
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#              <div id="qpeTitleTag_feature_div" class="feature" data-feature-name="qpeTitleTag">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#              <div id="bylineInfo_feature_div" class="feature" data-feature-name="bylineInfo">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <div class="a-section a-spacing-none">
#
#
#                     by
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
end = raw1.find('</span>')
print(raw1[:end])
# Out:
#
#
#
#
#
#
#
#
#                         All-new Echo Dot (3rd Gen) - Smart speaker with Alexa (Black)

# %%
strat = content
